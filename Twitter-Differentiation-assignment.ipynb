# %% [markdown]
# # Twitter Differentiation Assignment
# ## Anvesh Rokanlawar:
# In this assignment we will be analyzing the tweets made from three different accounts
# The 3 different accounts I had choosed are as follows:
# 1.Microsoft
# 2.facebook
# 3.Google

# %%
#Retrieve information from Twitter and store in pickle file (code)
import tweepy
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import pickle

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

microsoft_tweets = api.user_timeline('Microsoft')
facebook_tweets = api.user_timeline('facebook')
Google_tweets = api.user_timeline('Google')

with open('Microsoft.pkl', 'wb') as a:
    pickle.dump(microsoft_tweets, a)
with open('facebook.pkl', 'wb') as b:
    pickle.dump(facebook_tweets, b)
with open('Google.pkl', 'wb') as c:
    pickle.dump(Google_tweets, c)

# %%
#Load cached data from pickle file (code)
with open('Microsoft.pkl', 'rb') as a:
    microsoft_tweets = pickle.load(a)

print(microsoft_tweets)
with open('facebook.pkl', 'rb') as b:
    facebook_tweets = pickle.load(b)

print(facebook_tweets)
with open('Google.pkl', 'rb') as c:
    Google_tweets = pickle.load(c)

print(Google_tweets)
# Out:
# [Status(_json={'created_at': 'Tue Jun 18 00:21:24 +0000 2019', 'id': 1140776488914096128, 'id_str': '1140776488914096128', 'text': 'RT @HoloLens: See how @Airbus is using #Azure and #HoloLens2 to increase safety and functionality in their aircraft designs: https://t.co/F…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Azure', 'indices': [39, 45]}, {'text': 'HoloLens2', 'indices': [50, 60]}], 'symbols': [], 'user_mentions': [{'screen_name': 'HoloLens', 'name': 'Microsoft HoloLens', 'id': 2979430185, 'id_str': '2979430185', 'indices': [3, 12]}, {'screen_name': 'Airbus', 'name': 'Airbus', 'id': 15425377, 'id_str': '15425377', 'indices': [22, 29]}], 'urls': []}, 'source': '<a href="https://prod2.sprinklr.com" rel="nofollow">Sprinklr Publisher</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 74286565, 'id_str': '74286565', 'name': 'Microsoft', 'screen_name': 'Microsoft', 'location': 'Redmond, WA', 'description': 'We’re on a mission to empower every person and every organization on the planet to achieve more. Support: @MicrosoftHelps', 'url': 'https://t.co/bKBtZeAFrh', 'entities': {'url': {'urls': [{'url': 'https://t.co/bKBtZeAFrh', 'expanded_url': 'https://news.microsoft.com/', 'display_url': 'news.microsoft.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 8606017, 'friends_count': 2566, 'listed_count': 22902, 'created_at': 'Mon Sep 14 22:35:42 +0000 2009', 'favourites_count': 1658, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 15752, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '00AEEF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1103786517686771712/UvG4ZtYW_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1103786517686771712/UvG4ZtYW_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/74286565/1557879071', 'profile_link_color': '1570A6', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 17 19:30:31 +0000 2019', 'id': 1140703288360349696, 'id_str': '1140703288360349696', 'text': 'See how @Airbus is using #Azure and #HoloLens2 to increase safety and functionality in their aircraft designs:… https://t.co/CJVRIxehsG', 'truncated': True, 'entities': {'hashtags': [{'text': 'Azure', 'indices': [25, 31]}, {'text': 'HoloLens2', 'indices': [36, 46]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Airbus', 'name': 'Airbus', 'id': 15425377, 'id_str': '15425377', 'indices': [8, 15]}], 'urls': [{'url': 'https://t.co/CJVRIxehsG', 'expanded_url': 'https://twitter.com/i/web/status/1140703288360349696', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [112, 135]}]}, 'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2979430185, 'id_str': '2979430185', 'name': 'Microsoft HoloLens', 'screen_name': 'HoloLens', 'location': '', 'description': 'The official Twitter account of Microsoft HoloLens. Sign up for our newsletter: https://t.co/u ...
# [Status(_json={'created_at': 'Mon Jun 17 20:00:42 +0000 2019', 'id': 1140710882558861313, 'id_str': '1140710882558861313', 'text': "@Kurikurimaumau Hi there. You can first try using a different web browser. If Facebook still isn't loading properly… https://t.co/uUOvTzXgf1", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Kurikurimaumau', 'name': 'Meow', 'id': 4911198926, 'id_str': '4911198926', 'indices': [0, 15]}], 'urls': [{'url': 'https://t.co/uUOvTzXgf1', 'expanded_url': 'https://twitter.com/i/web/status/1140710882558861313', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://www.spredfast.com/" rel="nofollow">Spredfast app</a>', 'in_reply_to_status_id': 1140630989464432640, 'in_reply_to_status_id_str': '1140630989464432640', 'in_reply_to_user_id': 4911198926, 'in_reply_to_user_id_str': '4911198926', 'in_reply_to_screen_name': 'Kurikurimaumau', 'user': {'id': 2425151, 'id_str': '2425151', 'name': 'Facebook', 'screen_name': 'facebook', 'location': 'Menlo Park, California', 'description': 'Our mission is to give people the power to build community and bring the world closer together. Need help? Visit https://t.co/HpkLABTIyz.', 'url': 'http://t.co/7bZ2KCQJ2k', 'entities': {'url': {'urls': [{'url': 'http://t.co/7bZ2KCQJ2k', 'expanded_url': 'http://facebook.com', 'display_url': 'facebook.com', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/HpkLABTIyz', 'expanded_url': 'http://facebook.com/help', 'display_url': 'facebook.com/help', 'indices': [113, 136]}]}}, 'protected': False, 'followers_count': 13502434, 'friends_count': 718, 'listed_count': 43595, 'created_at': 'Tue Mar 27 07:29:25 +0000 2007', 'favourites_count': 1201, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 12553, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '3C5A99', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1123287311695982594/X4G0h2LY_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1123287311695982594/X4G0h2LY_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2425151/1506715336', 'profile_link_color': '3C5A99', 'profile_sidebar_border_color': 'DEDEDE', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 6, 17, 20, 0, 42), id=1140710882558861313, id_str='1140710882558861313', text="@Kurikurimaumau Hi there. You can first try using a different web browser. If Facebook still isn't loading properly… https://t.co/uUOvTzXgf1", truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Kurikurimaumau', 'name': 'Meow', 'id': 4911198926, 'id_str': '4911198926', 'indices': [0, 15]}], 'urls': [{'url': 'https://t.co/uUOvTzXgf1', 'expanded_url': 'https://twitter.com/i/web/status/1140710882558861313', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Spredfast app', source_url='https://www.spredfast.com/', in_reply_to_status_id=1140630989464432640, in_reply_to_status_id_str='1140630989464432640', in_reply_to_user_id=4911198926, in_reply_to_user_id_str='4911198926', in_reply_to_screen_name='K ...
# [Status(_json={'created_at': 'Mon Jun 17 23:56:58 +0000 2019', 'id': 1140770341100445702, 'id_str': '1140770341100445702', 'text': '@kyotomumfes おはようございます。ツイートをお見かけしました。Google One は、Google フォトや Gmail など共通の保存容量を追加で定期購入できるプランです。また、さまざまな特典をご利用いただけるほか… https://t.co/AqsekLAhRA', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kyotomumfes', 'name': '京都マムフェス【出店者募集中】京都最大級ママイベント', 'id': 3405080113, 'id_str': '3405080113', 'indices': [0, 12]}], 'urls': [{'url': 'https://t.co/AqsekLAhRA', 'expanded_url': 'https://twitter.com/i/web/status/1140770341100445702', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://www.conversocial.com" rel="nofollow">Conversocial</a>', 'in_reply_to_status_id': 1140633738348417030, 'in_reply_to_status_id_str': '1140633738348417030', 'in_reply_to_user_id': 3405080113, 'in_reply_to_user_id_str': '3405080113', 'in_reply_to_screen_name': 'kyotomumfes', 'user': {'id': 20536157, 'id_str': '20536157', 'name': 'Google', 'screen_name': 'Google', 'location': 'Mountain View, CA', 'description': '#HeyGoogle', 'url': 'https://t.co/ZKjExFWujb', 'entities': {'url': {'urls': [{'url': 'https://t.co/ZKjExFWujb', 'expanded_url': 'http://about.google', 'display_url': 'about.google', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 21171773, 'friends_count': 215, 'listed_count': 96191, 'created_at': 'Tue Feb 10 19:14:39 +0000 2009', 'favourites_count': 2298, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 98393, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1057899591708753921/PSpUS-Hp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1057899591708753921/PSpUS-Hp_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20536157/1557769801', 'profile_link_color': '0000CC', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEFF9', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ja'}, created_at=datetime.datetime(2019, 6, 17, 23, 56, 58), id=1140770341100445702, id_str='1140770341100445702', text='@kyotomumfes おはようございます。ツイートをお見かけしました。Google One は、Google フォトや Gmail など共通の保存容量を追加で定期購入できるプランです。また、さまざまな特典をご利用いただけるほか… https://t.co/AqsekLAhRA', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kyotomumfes', 'name': '京都マムフェス【出店者募集中】京都最大級ママイベント', 'id': 3405080113, 'id_str': '3405080113', 'indices': [0, 12]}], 'urls': [{'url': 'https://t.co/AqsekLAhRA', 'expanded_url': 'https://twitter.com/i/web/status/1140770341100445702', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Conversocial', source_url='http://www.conversocial.com', in_reply_to_status_id=1140633738348417030, in_reply_to_status_id_str='1140633738348417030', in_reply_to_user_id=3405080113, in_reply_to_user_id_str='3405080113', in_reply_to_screen_name='kyotomumfes', author=User(_json={'id': 20536157, 'id_str': '20536157', 'name': 'Google', 'screen_name': 'Google', 'location': 'Mountain View, CA', 'description': '#HeyGoogle', 'url': 'https://t.co/ZKjExFWujb', 'entities': {'url': {'urls': [{'url': 'https://t.co/ZK ...
